# %% [markdown]
# # 1. 머신러닝
# * 인공지능: 인공(Artificial) + 지능(Interlligence)
#   * 개발자에 의한 인공지능, 데이터에 의한 인공지능
# * 머신러닝: 데이터를 기반으로 한 학습(Learning)하는 기계(machine)
# * 딥러닝: 깊은(deep)신경망 구조의 머신러닝

# %% [markdown]
# ### 1-1. 배경
# * 과거 컴퓨터로 데이터를 읽어들이고, 데이터 안에서 특징을 학습하여 패턴을 찾아내는 작업 ->> 패턴 인식
# * 데이터를 대량으로 수집 처리할 수 있는 환경이 갖춰짐으로 할 수 있는 일들이 많아짐
# * 머신러닝은 데이터로부터 특징이나 페턴을 찾아내는 것이기 때문에 데이터가 가장 중요함

# %% [markdown]
# ### 1-2. 정의
# * 인공지능의 한 분야로 컴퓨터가 학습할 수 있도록 하는 알고리즘과 기술을 개발하는 분야
# * "무엇(x)으로 무엇(y)을 예측하고 싶다"의 f(함수)를 찾아내는 것 ax + b = y
# * y: 출력변수(종속변수) 데이터에 주어진 정답
# * x: 입력변수(독립변수), f:모형(머신러닝 알고리즘)

# %% [markdown]
# ### 2-1. 회귀
# * 시계열(시간적인 변화를 연속적으로 관측한 데이터)데이터 같은 연속된 데이터를 취급할 떄 사용하는 기법
# * 예) 과거 주식 추세를 학습해서 내일의 주가를 예측하는 시스템 개발

# %% [markdown]
# ### 2-2 분류(Classification)
# * 주어진 데이터를 클래스별로 구별해 내는 과정으러 데이터와 데이터의 레이블값을 학습시키고 어느 범중 속한 데이터인지 판단하고 예측
# * 예) 스팸메일인지 아닌지 구별해주는 시스템을 개발

# %% [markdown]
# ### 2-3. 클러스터링(Clusering)
# * 분류와 비슷라지만 데이터에 리이블(정답 데이터)없음
# * 유사한 속성들을 갖는 데이터를 일정한 수의 군집으로 그룹핑하는 비지도 학습
# * 예) SNS 데이터를 통해 소셜 밒 사회 이슈를 파악

# %% [markdown]
# # 3.학습

# %% [markdown]
# ### 3-1.지도 학습
# * 문제와 정답을 모두 학습시켜 예측 또는 분류하느 문제
# * t=f(x)에 대하야ㅕ 입력변수 (x)와 출력 변수(y)의 관계에 대하여 모델링하는것
# * y에 대하여 예측또는 분류하는 문제

# %% [markdown]
# ### 3-2.비지도 학습

# %% [markdown]
# * 출력변수(y)가 존재하지 않고, 입력변수(x)간의 관계에 대해 모델링하는것
# * 군집분석: 유사한 데이터끼리 그룹화
# * PCA: 독립변수들의 차원의 축소화

# %% [markdown]
# ### 3-3 강화학습
# * 수 많은 시뮬레이션을 통해 현재의 선택이 미래에 보상이 최대로 되도록 학습
